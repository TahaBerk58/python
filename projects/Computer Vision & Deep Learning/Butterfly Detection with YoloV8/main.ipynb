# %%
# !pip install ultralytics
# !pip install opencv-python-headless
# !pip install labelme
# !pip install albumentations
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.4/799.4 kB 3.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
import os
import cv2
import random
import albumentations as A
from ultralytics import YOLO
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

# %%
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 82.8MB/s]

# %%
model.train(data="/content/drive/MyDrive/Projeler/project2/butterflydata/data.yaml", epochs=20)
metrics = model.val()
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
#Test Model
# !yolo model=/content/runs/detect/train/weights/best.pt mode=predict source=/content/drive/MyDrive/Projeler/project2/butterflydata/Image_101.jpg name=butterfly exist_ok=True
# !yolo model=/content/runs/detect/train/weights/best.pt mode=predict source=/content/drive/MyDrive/Projeler/project2/butterflydata/testvideo.mp4 name=butterflyvideo exist_ok=True
# !yolo model=/content/runs/detect/train/weights/best.pt mode=predict source=/content/drive/MyDrive/Projeler/project2/butterflydata/testvideo/2616619-hd_1920_1080_30fps.mp4 name=butterflyvideo1 exist_ok=True
# !yolo model=/content/runs/detect/train/weights/best.pt mode=predict source=/content/drive/MyDrive/Projeler/project2/butterflydata/testvideo/2901459-hd_1920_1080_30fps.mp4 name=butterflyvideo2 exist_ok=True
# !yolo model=/content/runs/detect/train/weights/best.pt mode=predict source=/content/drive/MyDrive/Projeler/project2/butterflydata/testvideo/4977160-hd_1920_1080_25fps.mp4 name=butterflyvideo3 exist_ok=True
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Projeler/project2/butterflydata/Image_101.jpg: 640x640 1 butterfly, 434.5ms
# Speed: 14.8ms preprocess, 434.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/butterfly
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/903) /content/drive/MyDrive/Projeler/project2/butterflydata/testvideo.mp4: 384x640 1 butterfly, 190.2ms
# video 1/1 (frame 2/903) /content/drive/MyDrive/Projeler/project2/butterflydata/testvideo.mp4: 384x640 1 butterfly, 170.1ms
# ...
