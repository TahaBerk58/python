# %%
# !pip install ultralytics
# !pip install opencv-python-headless
# !pip install labelme
# !pip install albumentations

# %%
import os
import cv2
import random
import albumentations as A
from ultralytics import YOLO
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(data="/content/drive/MyDrive/Projeler/hardhatsample/data/data.yaml", epochs=20)
metrics = model.val()
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo model=/content/runs/detect/train6/weights/best.pt mode=predict source=/content/drive/MyDrive/Projeler/hardhatsample/data/test/images name=butterfly exist_ok=True
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/10 /content/drive/MyDrive/Projeler/hardhatsample/data/test/images/000008_jpg.rf.YUW4RJzfymTyi1i75xBs.jpg: 640x640 2 helmets, 1 person, 279.5ms
# image 2/10 /content/drive/MyDrive/Projeler/hardhatsample/data/test/images/000011_jpg.rf.t0j21FpZTz61nTGKiK1d.jpg: 640x640 1 head, 15 helmets, 235.9ms
# image 3/10 /content/drive/MyDrive/Projeler/hardhatsample/data/test/images/000034_jpg.rf.aNFSKjDSVTFu2UTSKOYj.jpg: 640x640 1 helmet, 232.5ms
# image 4/10 /content/drive/MyDrive/Projeler/hardhatsample/data/test/images/000047_jpg.rf.whOXhStb5F7WXFd7JUCJ.jpg: 640x640 6 helmets, 230.3ms
# image 5/10 /content/drive/MyDrive/Projeler/hardhatsample/data/test/images/000054_jpg.rf.nJCr5cs9ET9ZhXc5ORBv.jpg: 640x640 1 helmet, 215.0ms
# ...

# %%
# !yolo model=/content/drive/MyDrive/Projeler/hardhatsample/runs/detect/train6/weights/best.pt mode=predict source=/content/8853484-hd_1080_1920_24fps.mp4 name=butterfly2 exist_ok=True
# !yolo model=/content/drive/MyDrive/Projeler/hardhatsample/runs/detect/train6/weights/best.pt mode=predict source=/content/8853529-hd_1920_1080_24fps.mp4 name=butterfly2 exist_ok=True
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/250) /content/8853484-hd_1080_1920_24fps.mp4: 640x384 1 helmet, 180.5ms
# video 1/1 (frame 2/250) /content/8853484-hd_1080_1920_24fps.mp4: 640x384 1 helmet, 150.9ms
# video 1/1 (frame 3/250) /content/8853484-hd_1080_1920_24fps.mp4: 640x384 1 helmet, 150.1ms
# video 1/1 (frame 4/250) /content/8853484-hd_1080_1920_24fps.mp4: 640x384 1 helmet, 153.1ms
# video 1/1 (frame 5/250) /content/8853484-hd_1080_1920_24fps.mp4: 640x384 1 helmet, 146.7ms
# video 1/1 (frame 6/250) /content/8853484-hd_1080_1920_24fps.mp4: 640x384 1 helmet, 161.2ms
# video 1/1 (frame 7/250) /content/8853484-hd_1080_1920_24fps.mp4: 640x384 1 helmet, 149.9ms
# video 1/1 (frame 8/250) /content/8853484-hd_1080_1920_24fps.mp4: 640x384 1 helmet, 155.5ms
# ...

# %%
# !yolo model=/content/drive/MyDrive/Projeler/hardhatsample/runs/detect/train6/weights/best.pt mode=predict source=/content/8964793-uhd_3840_2160_25fps.mp4 name=butterfly3 exist_ok=True
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/337) /content/8964793-uhd_3840_2160_25fps.mp4: 384x640 3 helmets, 167.4ms
# video 1/1 (frame 2/337) /content/8964793-uhd_3840_2160_25fps.mp4: 384x640 3 helmets, 166.4ms
# video 1/1 (frame 3/337) /content/8964793-uhd_3840_2160_25fps.mp4: 384x640 3 helmets, 150.4ms
# video 1/1 (frame 4/337) /content/8964793-uhd_3840_2160_25fps.mp4: 384x640 3 helmets, 192.3ms
# video 1/1 (frame 5/337) /content/8964793-uhd_3840_2160_25fps.mp4: 384x640 3 helmets, 161.2ms
# video 1/1 (frame 6/337) /content/8964793-uhd_3840_2160_25fps.mp4: 384x640 3 helmets, 149.2ms
# video 1/1 (frame 7/337) /content/8964793-uhd_3840_2160_25fps.mp4: 384x640 3 helmets, 162.6ms
# video 1/1 (frame 8/337) /content/8964793-uhd_3840_2160_25fps.mp4: 384x640 3 helmets, 164.7ms
# ...
